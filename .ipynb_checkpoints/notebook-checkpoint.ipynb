# %%
# docker run -p 8888:8888 jupyter/datascience-notebook:latest
import os
import datetime
import numpy as np
import pandas as pd

import qgrid
qgrid.enable()
# qgrid.disable()

import api
import bars

# %load_ext autoreload
# %autoreload 2

# import ipdb; ipdb.set_trace(context=10)
# import pudb; pu.db

# %%
symbol='GLD'
fmat = 'parquet'
date = '2019-05-09'

ts = bars.read_matching_files(f"../data/ticks/{fmat}/{symbol}/{symbol}_{date}.{fmat}", format=fmat)
ts = bars.add_datetime(ts)

# %%
dr = pd.date_range(start='2019-05-09', end='2019-05-10', freq='5min', tz='utc')
for i in list(range(len(dr))):
    ticks = ts[(ts.date_time >= dr[i]) & (ts.date_time < dr[i+1])]
# Out:
# 289

# %%
# bw = "scott"
bw = "silverman"
# bw = "normal_reference"
# bw = 0.004

kde1= KDEUnivariate(ticks['price'].values)

kde1.fit(weights=ticks['volume'].values, 
         bw=bw,
         fft=False)

# “scott” - 1.059 * A * nobs ** (-1/5.), where A is min(std(X),IQR/1.34)
# “silverman” - .9 * A * nobs ** (-1/5.), where A is min(std(X),IQR/1.34)
# "normal_reference" - C * A * nobs ** (-1/5.), where C is

# plt.plot(kde1.support, [kde1.evaluate(xi) for xi in kde1.support], 'o-')
plt.plot(kde1.support, kde1.cdf, 'x-')

# kde1.fit(bw=bw,
#          fft=False)

# plt.plot(kde1.support, [kde1.evaluate(xi) for xi in kde1.support], 'x-')

# %%
kde1.support[kde1.cdf > .5][0]
# Out:
# 121.21006670381588

# %%
import matplotlib.pyplot as plt
from statsmodels.nonparametric.kde import KDEUnivariate

kde1= KDEUnivariate(np.array([10.,10.,10.,5.]))
kde1.fit(bw=0.5)
plt.plot(kde1.support, [kde1.evaluate(xi) for xi in kde1.support],'x-')

kde1= KDEUnivariate(np.array([10.,5.]))
kde1.fit(weights=np.array([3.,1.]), 
         bw=0.5,
         fft=False)
plt.plot(kde1.support, [kde1.evaluate(xi) for xi in kde1.support], 'o-')

# %%
i = 203
print(dr[i])
ticks = ts[(ts.date_time >= dr[i]) & (ts.date_time < dr[i+1])]
ticks
# Out:
# 2019-05-09 16:55:00+00:00
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': True, 'defau…

# %%
state = bars.reset_state()
output_bars = []
nrow = 0

while nrow < len(ts):
       
    input_tick = {}
    input_tick['epoch'] = ts['epoch'][nrow]
    input_tick['price'] = ts['price'][nrow]
    input_tick['volume'] = ts['volume'][nrow]

    output_bars, state = bars.update_bar(input_tick, output_bars, state)
    
    nrow += 1

# %%
pd.to_datetime(output_bars[2]['close_time'])

# %%
pd.DataFrame(output_bars)
