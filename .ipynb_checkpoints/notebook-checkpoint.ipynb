# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd
import pandas_bokeh
from qgrid import show_grid
# import finplot as fplt

import polygon_rest_api as papi
import polygon_backfill as pb
import polygon_s3 as ps3
import bar_samples as bs
import bar_labels as bl

import filters as ft
# import market_cluster as mc

import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20, 7]
from matplotlib import style
style.use('fivethirtyeight')

# from tqdm import tqdm
# import ipdb
# ipdb.set_trace(context=10)

# df.style.background_gradient(cmap='coolwarm', axis=None, vmin=-1, vmax=1)  # 'Blues', 'coolwarm', 'RdBu_r' & 'BrBG' are other good diverging colormaps
# pd.set_option('precision', 2)

# get local market daily data
# mdf = pd.read_parquet('data/mdf.parquet')

# .plot_bokeh(sizing_mode="scale_height")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
symbol='GLD'
# symbol = 'market'
date = '2020-01-02'
start_date = '2020-01-01'
end_date = '2020-01-10'
# symbols=['SPY', 'QQQ']
tick_type='trades'
# tick_type = None

result_path = '/Users/bobcolner/QuantClarity/pandas-polygon/data'

thresh = {
    # GT thresholds
    'renko_reveral_multiple': 2,
    'duration_sec': 60*30,
#     'tick_imbalance': 150,
    # LT thresholds 
    'min_duration_sec': 15,
    'min_tick_count': 30,
}

# %%
import ray
ray.init(ignore_reinit_error=True)

@ray.remote
def build_bars_ray(result_path, symbol, date, thresh) -> dict:
    ticks_df = ps3.load_ticks(result_path, symbol, date, 'trades')
    # print(date)
    # ticks_df = pd.read_feather(result_path + f"/trades/symbol={symbol}/date={date}/data.feather")
    bars, state = bs.build_bars(ticks_df, thresh)
    return {'date': date, 'bars': bars}
#     return bars
# Out:
# 2020-10-25 00:58:48,487	INFO services.py:1166 -- View the Ray dashboard at http://127.0.0.1:8265

# %%
daily_vol_df = ps3.get_symbol_vol_filter(result_path, symbol, start_date)

futures = []

for row in daily_vol_df.itertuples():
    
    thresh.update({'renko_size': row.range_jma / 15})

    bars = build_bars_ray.remote(
        result_path=result_path,
        symbol=symbol, 
        date=row.date,
        thresh=thresh
    )
    futures.append(bars)
    
bar_dates = ray.get(futures)

ray.shutdown()

# %%
bar_dates[3]['date']
# Out:
# '2020-01-22'

# %%
bar_dates[3]['bars'][49]
# Out:
# {'bar_trigger': 'renko_down',
#  'open_at': Timestamp('2020-01-23 00:20:49.805657199'),
#  'close_at': Timestamp('2020-01-23 00:37:29.466198896'),
#  'duration_td': Timedelta('0 days 00:16:39.660541697'),
#  'duration_sec': 999,
#  'duration_min': 16,
#  'price_open': 147.13999938964844,
#  'price_close': 147.0,
#  'price_low': 147.0,
#  'price_high': 147.13999938964844,
#  'price_range': 0.1399993896484375,
#  'bar_return': -0.1399993896484375,
#  'price_wq10': 147.0,
#  'price_wq50': 147.0,
#  'price_wq90': 147.13999938964844,
#  'price_wmean': 147.0516809968867,
#  'price_wstd': 0.060201699979086656,
#  'ticks': 4,
#  'volume': 351,
#  'dollars': 51615.14002990723,
#  'tick_imbalance': -1,
#  'volume_imbalance': -299,
#  'dollar_imbalance': -43963.86006164551,
#  'tick_imbalance_run': 0,
#  'volume_imbalance_run': 0,
#  'dollar_imbalance_run': 0}

# %%
bar_dates[3]['bars'][49]['tick_imbalance']
# Out:
# -1

# %%
s.quantile(q=.8)
# Out:
# 3.0

# %%
stats = {}
for date_d in bar_dates:
    
    imbalances = []    
    for bar in date_d['bars']:
        imbalances.append(bar['tick_imbalance'])
    
    imbal_q80 = pd.Series(imbalances).quantile(q=.8)
    stats[date_d['date']] = imbal_q80

# %%
pd.Series(stats).plot()
# Out:
# <AxesSubplot:>

# %%
pd.Series(stats).describe()
# Out:
# count    195.000000
# mean      35.985641
# std       28.431234
# min        2.000000
# 25%       16.900000
# 50%       27.800000
# 75%       49.600000
# max      160.000000
# dtype: float64

# %%
pd.Series(stats).hist(bins=40)
# Out:
# <AxesSubplot:>

# %%
abs(pd.Series(ti)).describe(percentiles=[.1,.2,.8,.9])

# %%
bar_ti = [bar['tick_imbalance'] for bar in bar_dates['2020-10-12']]

abs(pd.Series(bar_ti)).describe(percentiles=[.1,.2,.8,.9])

# %%
bar_counts =  [len(bars) for date, bars in bar_dates.items()]
pd.Series(bar_counts).describe(percentiles=[.1,.2,.8,.9])

# %%
bar_counts =  [len(bars) for bars in bar_dates]
pd.Series(bar_counts).describe(percentiles=[.1,.2,.8,.9])

# %%
show_grid(pd.DataFrame(bar_dates[open_dates[2]])[['bar_trigger','open_at','close_at','duration_min','ticks','price_wmean']])

# %%
# range / price = HFT profit potential
(df.price.max() - df.price.min()) / df.price.mean()

# %%
# label bars
label_horizon_mins = 30
risk_level = 0.2
# reward_base = 1
reward_ratios = np.arange(3, 20, .5)

lbars = bl.label_bars(bars, ticks_df, risk_level, label_horizon_mins, reward_ratios)

lbars_df = pd.DataFrame(lbars)

lbars_unq = bl.get_concurrent_stats(lbars_df)
print(lbars_unq['grand_avg_unq'])

# %%
lbars_df[['price_wmean', 'label_rrr']].plot_bokeh(sizing_mode="scale_height")
# 17, 31

# %%
lbars_df[['price_wmean', 'label_rrr']].plot(subplots=True, figsize=[17,12])

# %%
df[['range', 'range_jma']].plot()
# df2[['range', 'range_jma']].plot_bokeh(sizing_mode="scale_height")
