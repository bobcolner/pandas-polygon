# %%
import ray
ray.shutdown()

# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd
import pandas_bokeh
from qgrid import show_grid
# import finplot as fplt

import polygon_rest_api as papi
import polygon_backfill as pb
import polygon_s3 as ps3
import bar_samples as bs
import bar_labels as bl
import bar_meta as bm
import filters as ft
# import market_cluster as mc

import matplotlib as mpl
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20, 7]


import ray
ray.init(ignore_reinit_error=True, num_cpus=4, dashboard_port=8080)

# from tqdm import tqdm
# import ipdb
# ipdb.set_trace(context=10)

# df.style.background_gradient(cmap='coolwarm', axis=None, vmin=-1, vmax=1)  # 'Blues', 'coolwarm', 'RdBu_r' & 'BrBG' are other good diverging colormaps
# pd.set_option('precision', 2)

# .plot_bokeh(sizing_mode="scale_height")
# Out:
# 2020-10-29 15:00:22,955	INFO services.py:1166 -- View the Ray dashboard at http://127.0.0.1:8080
# {'node_ip_address': '192.168.50.218',
#  'raylet_ip_address': '192.168.50.218',
#  'redis_address': '192.168.50.218:6379',
#  'object_store_address': '/tmp/ray/session_2020-10-29_15-00-22_415111_9268/sockets/plasma_store',
#  'raylet_socket_name': '/tmp/ray/session_2020-10-29_15-00-22_415111_9268/sockets/raylet',
#  'webui_url': '127.0.0.1:8080',
#  'session_dir': '/tmp/ray/session_2020-10-29_15-00-22_415111_9268',
#  'metrics_export_port': 64369}

# %%
symbol='GLD'
# symbol = 'market'
# date = '2020-01-02'
# start_date = '2020-01-01'
start_date = '2020-09-01'
end_date = '2020-10-01'
# symbols=['SPY', 'QQQ']
tick_type='trades'

result_path = '/Users/bobcolner/QuantClarity/pandas-polygon/data'

thresh = {
    # GT thresholds
    'renko_reveral_multiple': 2,
    'duration_sec': 60*60,
    # LT thresholds
    'min_duration_sec': 15,
    'min_tick_count': 30,
}

horizon_mins=30

# %%
daily_bar_stats_df, labeled_bar_dates, stacked_bars_df = bm.bars_workflow_ray(
    result_path, 
    symbol, 
    start_date, 
    end_date, 
    thresh,
    imbalance_thresh=0.95
)

# %%
daily_bar_stats_df
# Out:
#           date  bar_count  imbalance_thresh  duration_min_mean  \
# 0   2020-09-04         64          53833.15          14.593750
# 1   2020-09-08         73          26891.40          12.337443
# 2   2020-09-09         36          64259.50          24.849537
# 3   2020-09-10         50          17715.50          18.098000
# 4   2020-09-11         30          57335.00          29.127778
# 5   2020-09-14         26         189080.50          35.805769
# 6   2020-09-15         35          25597.70          25.215238
# 7   2020-09-16         83          42936.80          11.139759
# 8   2020-09-17         59          44456.40          15.954237
# 9   2020-09-18         36         137361.50          25.240278
# 10  2020-09-21        142          32719.30           6.679108
# 11  2020-09-22         70          28533.55          13.390000
# 12  2020-09-23         90          42145.40          10.335000
# 13  2020-09-24         58          35900.15          15.401149
# 14  2020-09-25         38          47911.35          23.575877
# 15  2020-09-28         36          85557.75          25.892593
# 16  2020-09-29         29          68446.60          31.688506
# 17  2020-09-30         48          29192.10          19.063889
# 18  2020-10-01         46          41152.75          20.203623
#
#     duration_min_median                                             thresh  \
# 0              5.658333  {'renko_reveral_multiple': 2, 'duration_sec': ...
# 1              6.550000  {'renko_reveral_multiple': 2, 'duration_sec': ...
# 2             12.908333  {'renko_reveral_multiple': 2, 'duration_sec': ...
# 3             12.733333  {'renko_reveral_multiple': 2, 'duration_sec': ...
# 4             21.891667  {'renko_reveral_multiple': 2, 'duration_sec': ...
# 5             33.125000  {'renko_reveral_multiple': 2, 'duration_sec': ...
# 6             21.383333  {'renko_reveral_multiple': 2, 'duration_sec': ...
# 7              4.566667  {'renko_reveral_multiple': 2, 'duration_sec': ...
# 8              8.250000  {'renko_reveral_multiple': 2, 'duration_sec': ...
# 9             16.625000  {'renko_reveral_multiple': 2, 'duration_sec': ...
# 10             2.358333  {'renko_reveral_multiple': 2, 'duration_sec': ...
# 11             6.375000  {'renko_reveral_multiple': 2, 'duration_sec': ...
# 12             4.908333  {'renko_reveral_multiple': 2, 'duration_sec': ...
# 13             8.741667  {'renko_reveral_multiple': 2, 'duration_sec': ...
# 14            16.350000  {'renko_reveral_multiple': 2, 'duration_sec': ...
# 15            20.308333  {'renko_reveral_multiple': 2, 'duration_sec': ...
# 16            27.316667  {'renko_reveral_multiple': 2, 'duration_sec': ...
# 17            10.800000  {'renko_reveral_multiple': 2, 'duration_sec': ...
# 18            12.483333  {'renko_reveral_multiple': 2, 'duration_sec': ...
#
#     imbalance_thresh_jma  imbalance_thresh_jma_lag symbol    volume  \
# 0           49004.960678              45460.000000    GLD  11653269
# 1           39414.412741              49004.960678    GLD  13700587
# 2           44978.242495              39414.412741    GLD   8504675
# 3           40557.547335              44978.242495    GLD   9259303
# 4           42009.463052              40557.547335    GLD   7718562
# 5           69425.094152              42009.463052    GLD   9774427
# 6           75170.616615              69425.094152    GLD   7503988
# 7           69864.114367              75170.616615    GLD  12700143
# 8           62142.892900              69864.114367    GLD   8945082
# 9           72268.494788              62142.892900    GLD   9882464
# 10          70910.621160              72268.494788    GLD  17616392
# 11          61724.576272              70910.621160    GLD   8048907
# 12          53720.024782              61724.576272    GLD  18549112
# 13          47307.170760              53720.024782    GLD  11888518
# 14          44899.303481              47307.170760    GLD   6838013
# 15          51561.078883              44899.303481    GLD   7149944
# 16          58144.255021              51561.078883    GLD   8573230
# 17          55653.666060              58144.255021    GLD   8351316
# 18          51222.407889              55653.666060    GLD  10382775
#
#           open       close        high         low        vwap  date_time  \
# 0   180.949997  181.639999  182.100006  180.050003  181.014603 2020-09-04
# 1   179.500000  181.289993  182.270004  179.020004  180.659393 2020-09-08
# 2   182.500000  183.050003  183.220001  182.190002  182.792892 2020-09-09
# 3   184.229996  182.460007  184.679993  182.279999  183.516296 2020-09-10
# 4   183.139999  182.449997  183.549896  182.005005  182.666000 2020-09-11
# 5   183.570007  183.889999  184.300003  183.389999  183.806503 2020-09-14
# 6   184.460007  183.449997  184.669998  182.919998  183.629807 2020-09-15
# 7   184.979996  183.970001  185.009995  183.330002  184.281296 2020-09-16
# 8   181.919998  182.960007  183.089996  181.479996  182.493607 2020-09-17
# 9   183.070007  183.199997  184.089996  182.639999  183.262695 2020-09-18
# 10  179.839996  179.520004  180.289993  176.750000  178.871796 2020-09-21
# 11  179.630005  178.649994  180.020004  178.110001  178.840302 2020-09-22
# 12  176.979996  174.789993  177.259995  174.100006  175.320999 2020-09-23
# 13  174.360001  175.440002  176.235001  173.770004  175.038406 2020-09-24
# 14  174.410004  174.940002  175.300003  173.889999  174.865204 2020-09-25
# 15  175.830002  176.699997  176.804993  175.089996  176.125397 2020-09-28
# 16  177.179993  178.190002  178.330002  176.949997  177.698898 2020-09-29
# 17  177.710007  177.119995  178.610001  176.660004  177.546204 2020-09-30
# 18  178.690002  178.699997  179.500000  178.037506  178.901306 2020-10-01
#
#     dollar_total     range  range_jma  range_jma_lag
# 0   2.109412e+09  2.050003   2.133063       2.233240
# 1   2.475140e+09  3.250000   2.244804       2.133063
# 2   1.554594e+09  1.029999   2.120655       2.244804
# 3   1.699233e+09  2.399994   2.074046       2.120655
# 4   1.409919e+09  1.544891   2.037912       2.074046
# 5   1.796603e+09  0.910004   1.921343       2.037912
# 6   1.377956e+09  1.750000   1.821682       1.921343
# 7   2.340399e+09  1.679993   1.753089       1.821682
# 8   1.632420e+09  1.610001   1.706051       1.753089
# 9   1.811087e+09  1.449997   1.661674       1.706051
# 10  3.151076e+09  3.539993   1.779801       1.661674
# 11  1.439469e+09  1.910004   1.892803       1.779801
# 12  3.252049e+09  3.159988   2.058504       1.892803
# 13  2.080947e+09  2.464996   2.201039       2.058504
# 14  1.195731e+09  1.410004   2.222766       2.201039
# 15  1.259287e+09  1.714996   2.174010       2.222766
# 16  1.523454e+09  1.380005   2.069682       2.174010
# 17  1.482744e+09  1.949997   1.986193       2.069682
# 18  1.857492e+09  1.462494   1.898789       1.986193

# %%
stacked_bars_df.bar_trigger.value_counts()
# Out:
# renko_down          493
# renko_up            491
# gap_filler          217
# volume_imbalance    108
# duration             94
# Name: bar_trigger, dtype: int64

# %%
daily_bar_stats_df.bar_count.describe()
# Out:
# count     19.000000
# mean      59.684211
# std       27.918637
# min       31.000000
# 25%       39.500000
# 50%       49.000000
# 75%       73.500000
# max      141.000000
# Name: bar_count, dtype: float64

# %%
bar_dates_df.price_wq50.diff().autocorr(1)

# %%
# bar_dates_df.price_wmean.plot_bokeh(sizing_mode="scale_height")
bar_dates_df[200:400].price_wmean.plot()

# %%
abs(bar_dates_df.label_rrr).value_counts()

# %%
mh_dates_df = bar_dates_df.loc[bar_dates_df.close_at.dt.hour.between(13, 20)]

# %%
mh_dates_df.label_outcome.value_counts()

# %%
lbars_df[['price_wmean', 'label_rrr']].plot_bokeh(sizing_mode="scale_height")
# 17, 31

# %%
lbars_df[['price_wmean', 'label_rrr']].plot(subplots=True, figsize=[17,12])
