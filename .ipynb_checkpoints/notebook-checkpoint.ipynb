# %%
# docker run -p 8888:8888 jupyter/datascience-notebook:latest
import os
import datetime
import numpy as np
import pandas as pd

import qgrid
qgrid.enable()
# qgrid.disable()
import pandas_bokeh
pandas_bokeh.output_notebook()
pd.set_option('plotting.backend', 'pandas_bokeh')

import api
import bars

# %load_ext autoreload
# %autoreload 2

# import ipdb; ipdb.set_trace(context=10)
# import pudb; pu.db
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
symbol='GLD'
fmat = 'parquet'
date = '2019-05-09'

ts = api.read_matching_files(f"../data/ticks/{fmat}/{symbol}/{symbol}_{date}.{fmat}", format=fmat)
ts = bars.epoch_to_dt(ts)

# %%
bars_5m = bars.time_bars(ts, date=date, freq='5min')
# Out:
# dropping zero volume tick
# {'epoch': 1557432600010354000, 'price': 121.2, 'volume': 0}
# dropping zero volume tick
# {'epoch': 1557441000010830000, 'price': 121.2, 'volume': 0}

# %%
bars_5m = bars_5m.set_index('time_open')

bars_5m[['first_tick_at', 'price_vwap', 'tick_count', 'volume_sum', 'tick_run_max', 'tick_imbalance']]
# Out:
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': True, 'defau…

# %%
bars_5m.price_vwap.plot(figsize=(1000, 500), rangetool=True)
# Out:
# ...
#   <div class="bk-root" id="e0e300b6-4792-4160-b975-3fe0b5fcdc76" data-root-id="6610"></div>
# Column(id='6610', ...)

# %%
tsi = ts.set_index('date_time')
tsi.price.plot(figsize=(1000, 500), rangetool=True, kind='line')
# Out:
# ...
#   <div class="bk-root" id="f9a8f5e2-8d4b-41e7-925b-de8e79305d4b" data-root-id="5359"></div>
# Column(id='5359', ...)

# %%
bars_5m.volume_sum.describe()
# Out:
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': True, 'defau…
