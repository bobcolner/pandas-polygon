# %%
# %load_ext autoreload
# %autoreload 2

import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20,7]
from matplotlib import style
style.use('fivethirtyeight')

import numpy as np
import pandas as pd
# import pandas_bokeh

import polygon_backfill as pb
import market_cluster as mc
import s3_datasets as s3d
import filters as ft
import local_backfill as lb
import bars as sb
import bar_labels as bl
import finplot as fplt

symbol='GLD'
date='2020-09-11'
tick_type='trades'
result_path='/Users/bobcolner/QuantClarity/pandas-polygon/data'
    
# .plot_bokeh(kind='hist', bins=50, sizing_mode="scale_height", disable_scientific_axes=True)
# df.style.background_gradient(cmap='coolwarm', axis=None, vmin=-1, vmax=1)  # 'Blues', 'coolwarm', 'RdBu_r' & 'BrBG' are other good diverging colormaps
# pd.set_option('precision', 2)

# get local market daily data
# mdf = pd.read_parquet('data/mdf.parquet')
# sdf = mdf[mdf.symbol=='SPY']
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
ticks_df = lb.load_ticks(symbol, date, result_path)

# %%
thresh = {
    # max. thresholds
    'renko_size': 0.1,
    'renko_reveral_multiple': 2,
    'duration_sec': 60*30,
    'tick_imbalance': 100,
    # min. thresholds    
    'min_duration_sec': 5,
    'min_tick_count': 5,
}
tdf = ticks_df[ticks_df.date_time.dt.hour >= 13]

# build bars
bars, _ = sb.build_bars(tdf, thresh)
len(bars)
# Out:
# 100%|██████████| 54733/54733 [00:01<00:00, 50538.56it/s]
# 95

# %%
max(label['label_outcome_at'], label['label_outcome_at'])
# Out:
# Timestamp('2020-09-11 16:45:14.598541312')

# %%
# label bars
label_horizon_mins = 45
risk_level = 0.15
reward_base = 1

# label_start_at = bars[45]['close_at']
# outcomes, label_prices = bl.triple_barrier_outcomes(ticks_df, label_start_at, risk_level, 
#                                                        label_horizon_mins, reward_base, debug=True)
# label = bl.outcomes_to_label(outcomes)

lbars = bl.label_bars_triple_barrier(bars, ticks_df, risk_level, label_horizon_mins, reward_base)
lbars_df = pd.DataFrame(lbars)
# Out:
# 100%|██████████| 95/95 [00:02<00:00, 39.21it/s]

# %%
lbars_df.label_rrr.value_counts(sort=False)
# Out:
#  0    67
# -2     2
#  2     5
#  3     2
#  4     3
#  5     1
# -3     8
# -4     5
# -5     2
# Name: label_rrr, dtype: int64

# %%
lbars_df[['price_mean', 'label_rrr']].plot(subplots=True, figsize=[16,12])
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>], dtype=object)
