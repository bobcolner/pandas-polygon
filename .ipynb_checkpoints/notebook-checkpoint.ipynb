# %%
import ray
ray.shutdown()

# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd
import pandas_bokeh
from qgrid import show_grid
# import finplot as fplt

import polygon_rest_api as papi
import polygon_ws_api as pws
import polygon_backfill as pb
import polygon_s3 as ps3
import bar_samples as bs
import bar_labels as bl
import bar_meta as bm
import filters as ft
# import market_cluster as mc

import matplotlib as mpl
from matplotlib import style
style.use('fivethirtyeight')
mpl.rcParams['figure.figsize'] = [20, 7]


# from tqdm import tqdm
# import ipdb
# ipdb.set_trace(context=10)

# df.style.background_gradient(cmap='coolwarm', axis=None, vmin=-1, vmax=1)  # 'Blues', 'coolwarm', 'RdBu_r' & 'BrBG' are other good diverging colormaps
# pd.set_option('precision', 2)

# .plot_bokeh(sizing_mode="scale_height")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
symbol='GLD'
# symbol = 'market'
# date = '2020-01-02'
# start_date = '2020-01-01'
start_date = '2019-01-01'
end_date = '2020-10-29'
# symbols=['SPY', 'QQQ']
tick_type='trades'

result_path = '/Users/bobcolner/QuantClarity/pandas-polygon/data'

thresh = {
    # GT thresholds
    'renko_reveral_multiple': 2,
    'duration_sec': 60*60,
    # LT thresholds
    'min_duration_sec': 15,
    'min_tick_count': 30,
}

horizon_mins=30

# %%
df = pd.DataFrame(labeled_bar_dates[2]['labeled_bars'])

# %%
abs(df.label_rrr).value_counts()
# Out:
# 0.0     32
# 4.0      4
# 3.0      3
# 6.0      3
# 5.0      2
# 7.0      2
# 8.0      1
# 11.0     1
# Name: label_rrr, dtype: int64

# %%
df[20:40]
# Out:
#          bar_trigger                    open_at                   close_at  \
# 20          renko_up 2019-01-08 14:55:32.509052 2019-01-08 14:56:42.439099
# 21        renko_down 2019-01-08 14:56:42.954567 2019-01-08 14:58:24.185071
# 22          renko_up 2019-01-08 14:58:24.243331 2019-01-08 15:00:37.369436
# 23  volume_imbalance 2019-01-08 15:00:37.369458 2019-01-08 15:04:44.162768
# 24        renko_down 2019-01-08 15:04:44.162788 2019-01-08 15:06:29.103433
# 25  volume_imbalance 2019-01-08 15:06:29.518657 2019-01-08 15:07:38.436388
# 26        renko_down 2019-01-08 15:07:38.436411 2019-01-08 15:09:23.318011
# 27        renko_down 2019-01-08 15:09:23.318030 2019-01-08 15:11:32.801223
# 28        renko_down 2019-01-08 15:11:33.300038 2019-01-08 15:13:49.726153
# 29          renko_up 2019-01-08 15:13:49.759028 2019-01-08 15:18:29.027507
# 30          renko_up 2019-01-08 15:18:29.067387 2019-01-08 15:32:16.666468
# 31          renko_up 2019-01-08 15:32:16.666825 2019-01-08 15:44:56.001996
# 32          duration 2019-01-08 15:44:57.647323 2019-01-08 16:45:00.810234
# 33        renko_down 2019-01-08 16:45:01.258222 2019-01-08 16:48:01.917392
# 34  volume_imbalance 2019-01-08 16:48:01.917417 2019-01-08 17:16:19.574255
# 35          renko_up 2019-01-08 17:16:19.574276 2019-01-08 17:30:50.935026
# 36          renko_up 2019-01-08 17:30:50.935080 2019-01-08 17:34:41.887789
# 37          renko_up 2019-01-08 17:34:42.088021 2019-01-08 17:36:04.971186
# 38          renko_up 2019-01-08 17:36:04.971259 2019-01-08 17:37:08.067853
# 39  volume_imbalance 2019-01-08 17:37:08.560142 2019-01-08 17:49:23.059183
#
#               duration_td  duration_sec  duration_min  price_open  \
# 20 0 days 00:01:09.930047          69.0      1.150000  121.500000
# 21          4.980372e+04        0.0     neutral        neutral
# 22          6.078100e+04       -7.0       short         profit
# 23          1.560782e+06       -5.0       short         profit
# 24          4.833397e+04       -4.0       short         profit
# 25          3.943964e+06       -3.0       short         profit
# 26          0.000000e+00        0.0     neutral        neutral
# 27          1.620963e+05        0.0     neutral        neutral
# 28          8.489414e+04        3.0        long         profit
# 29          4.975660e+04        0.0     neutral        neutral
# 30          0.000000e+00        0.0     neutral        neutral
# 31          5.572040e+05        0.0     neutral        neutral
# 32          1.214300e+04        0.0     neutral        neutral
# 33          1.213800e+04        0.0     neutral        neutral
# 34          2.440341e+05        6.0        long         profit
# 35          8.672643e+05        4.0        long         profit
# 36          0.000000e+00        3.0        long         profit
# 37          1.337230e+05        0.0     neutral        neutral
# 38          0.000000e+00        0.0     neutral        neutral
# 39          2.238360e+06        0.0     neutral        neutral
#
#              label_outcome_at  label_price_pct_change
# 20 2019-01-08 15:13:49.726153                0.000024
# 21 2019-01-08 15:06:29.103433                     NaN
# 22 2019-01-08 15:13:54.911324                0.000028
# 23 2019-01-08 15:13:53.999378                0.000020
# 24 2019-01-08 15:13:53.773304                0.000016
# 25 2019-01-08 15:13:50.001473                0.000012
# 26 2019-01-08 15:39:23.318011                     NaN
# 27 2019-01-08 15:18:29.730266                     NaN
# 28 2019-01-08 15:18:43.632946               -0.000012
# 29 2019-01-08 15:48:29.027507                     NaN
# 30 2019-01-08 15:44:56.001996                     NaN
# 31 2019-01-08 16:14:56.001996                     NaN
# 32 2019-01-08 17:15:00.810234                     NaN
# 33 2019-01-08 17:18:01.917392                     NaN
# 34 2019-01-08 17:36:04.985352               -0.000024
# 35 2019-01-08 17:36:04.980090               -0.000016
# 36 2019-01-08 17:36:04.980090               -0.000012
# 37 2019-01-08 18:06:04.971186                     NaN
# 38 2019-01-08 17:53:24.017478                     NaN
# 39 2019-01-08 18:19:23.059183                     NaN
#
# [20 rows x 31 columns]

# %%
import ray
ray.init(ignore_reinit_error=True, num_cpus=4, dashboard_port=8080)

daily_bar_stats_df, labeled_bar_dates, stacked_bars_df = bm.bars_workflow_ray( 
    symbol, 
    start_date, 
    end_date, 
    thresh,
    imbalance_thresh=0.9
)
import pickle 
fio = open('bars_workflow_ray.pickle', 'wb') 
pickle.dump((daily_bar_stats_df, labeled_bar_dates, stacked_bars_df), fio)

# %%
df = stacked_bars_df[1000:5000]
df = ft.add_multiple_jma_df(df, col='price_wmean', lengths=[7, 20, 100])

# %%
tdf = ps3.load_ticks(symbol, date='2019-03-19')
# Out:
# GLD 2019-03-19 trying to get ticks from local file...

# %%
df.loc[:, 'jma_100_diff'] = df.price_wmean - df.price_wmean_jma_100

# %%
# df.filter(like='price_wmean').plot_bokeh(sizing_mode="scale_height")
df.loc[6000:7000, ['price_wmean', 'price_wmean_jma_20']]
# Out:
# Empty DataFrame
# Columns: [price_wmean, price_wmean_jma_20]
# Index: []

# %%
mh_dates_df = bar_dates_df.loc[bar_dates_df.close_at.dt.hour.between(13, 20)]

# %%
mh_dates_df.label_outcome.value_counts()

# %%
lbars_df[['price_wmean', 'label_rrr']].plot_bokeh(sizing_mode="scale_height")
# 17, 31

# %%
lbars_df[['price_wmean', 'label_rrr']].plot(subplots=True, figsize=[17,12])

# %%
import flow_test as fb
fb.run_backfill(symbols=['GLD', 'GOLD'], tick_type='trades', start_date='2018-01-01')
